# %%
#imports
# !pip install git+https://gitlab.cern.ch/ssummers/run3_ugt_ml@axol1tl1_v2
# Out:
# ...
#   Cloning https://gitlab.cern.ch/ssummers/run3_ugt_ml (to revision axol1tl1_v2) to /private/var/folders/mn/rrdyn3f17ks_c0j8b5n3q3900000gn/T/pip-req-build-1g_bbrfq
#   Running command git clone --filter=blob:none --quiet https://gitlab.cern.ch/ssummers/run3_ugt_ml /private/var/folders/mn/rrdyn3f17ks_c0j8b5n3q3900000gn/T/pip-req-build-1g_bbrfq
# ...
#   Running command git checkout -b axol1tl1_v2 --track origin/axol1tl1_v2
# ...
#   Switched to a new branch 'axol1tl1_v2'
#   Branch 'axol1tl1_v2' set up to track remote branch 'axol1tl1_v2' from 'origin'.
#   Resolved https://gitlab.cern.ch/ssummers/run3_ugt_ml to commit b84c834b2a0f6722b78fd5e97d786e5d1868c7ef
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install git+https://gitlab.cern.ch/uhh-l1t/uhh_mlatl1_run3@pippackage!
# Out:
# ...
#   Cloning https://gitlab.cern.ch/uhh-l1t/uhh_mlatl1_run3 (to revision pippackage!) to /private/var/folders/mn/rrdyn3f17ks_c0j8b5n3q3900000gn/T/pip-req-build-3qtqz1k_
#   Running command git clone --filter=blob:none --quiet https://gitlab.cern.ch/uhh-l1t/uhh_mlatl1_run3 /private/var/folders/mn/rrdyn3f17ks_c0j8b5n3q3900000gn/T/pip-req-build-3qtqz1k_
# ...
#   WARNING: Did not find branch or tag 'pippackage!', assuming revision or ref.
#   Running command git checkout -q 'pippackage!'
#   error: pathspec 'pippackage!' did not match any file(s) known to git
#   error: subprocess-exited-with-error
#
#   × git checkout -q 'pippackage!' did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git checkout -q 'pippackage!' did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# ...

# %%
import uhh_mlatl1_run3 as uhh_mlatl1 # needs to use emulator tree!
import ugt_hls_emulator as ugt
from ast import literal_eval
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import mplhep
mplhep.style.use('CMS')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import uhh_mlatl1_run3 as uhh_mlatl1 # needs to use emulator tree!
#       2 import ugt_hls_emulator as ugt
#       3 from ast import literal_eval
#
# ModuleNotFoundError: No module named 'uhh_mlatl1_run3'
